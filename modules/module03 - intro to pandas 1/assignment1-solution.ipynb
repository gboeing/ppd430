# %%
def is_prime(n):
    
    if not isinstance(n, int):
        return False
    
    if n <= 1:
        return False
    
    for i in range(2, n):
        if n % i == 0:
            return False
        
    return True

print(is_prime(11))
print(is_prime(12))

# %%
def print_primes(n):
    for i in range(n + 1):
        if is_prime(i):
            print(i, end=' ')
            
print_primes(13)

# %%
def count_primes(n):
    counter = 0
    for i in range(n + 1):
        if is_prime(i):
            counter += 1
    return counter

count_primes(19)

# %%
def first_primes(n):
    primes = []
    i = 0
    while len(primes) < n:
        if is_prime(i):
            primes.append(i)
        i += 1
    return primes
            
first_primes(5)
