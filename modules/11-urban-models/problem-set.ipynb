# %% [markdown]
# # Problem set 9
#
# Make sure your notebook runs from the top without any errors and that all output can be seen inline (without me having to re-run your notebook). Click "Edit > Clear all outputs" and then "Runtime > Restart runtime". This clears your memory and re-initializes your notebook. Then click "Runtime > Run all" and make sure everything behaves properly. Then submit your notebook as a .ipynb file via Brightspace.

# %%
# !curl -s -o pyproject.toml https://raw.githubusercontent.com/gboeing/ppd430/refs/heads/main/pyproject.toml && uv pip install -q -r pyproject.toml

# %%
# load the census tract geometries shapefile and data CSV file we used in the lecture
# and then merge them together. load the rental listings CSV file, project it to the CRS
# of the tracts, then spatially join them like we demonstrated in the lecture

# %%
# estimate a simple regression model predicting asking rent as a function of the surrounding
# tract's median household income. then, add a markdown cell below this cell, and in it
# describe the relationship between these two variables in terms of sign, size, and
# significance, then interpret the real-world meaning of the results. what asking rent does
# your model predict in a tract with a $100,000 median household income?

# %%
# estimate a new model predicting rent as a function of 3-5 variables of your choosing.
# then, add a markdown cell below this cell, and in it explain why and how you chose these
# variables, and describe the relationship between the response and predictors in terms of
# sign, size, and significance. finally, interpret the real-world meaning of the results.

# %%
# create a correlation matrix and pairplots to see the relationships between your
# response and predictors. then log-transform your variables and do the same thing again.
# do these log-transformed predictors correlate better or worse with your log-transformed
# response than the original untransformed versions did?
